# %%
import pandas as pd
import os
import sys
import numpy as np


from itertools import chain

# %%
stories = pd.read_csv('data/train_stories.csv')
stories.set_index('storyid', inplace=True)
stories.head()
# Out:
#                                              storytitle  \
# storyid
# 8eb647c6-cdfa-416a-b4a2-09b24f44dcc5   Kelly Made Pizza
# e0cab669-993a-41be-978f-97795be07197  Embarrassing Hair
# ad2236b7-de48-45a2-838b-25f166bdee90       Grill Master
# 500fe4a4-f7c4-4f46-96ee-e010467b069f        Ice Skating
# 522f2bc3-3bb1-4f68-8e99-5b2abd016854       Bad friend 1
#
#                                                                               sentence1  \
# storyid
# 8eb647c6-cdfa-416a-b4a2-09b24f44dcc5  Kelly found her grandmother's pizza recipe in ...
# e0cab669-993a-41be-978f-97795be07197        Leo wore a toupee and was anxious about it.
# ad2236b7-de48-45a2-838b-25f166bdee90                 Jimmy was a master with his grill.
# 500fe4a4-f7c4-4f46-96ee-e010467b069f                          Tom and Beth were dating.
# 522f2bc3-3bb1-4f68-8e99-5b2abd016854  I had a friend that I didn't know well but let...
#
#                                                                               sentence2  \
# storyid
# 8eb647c6-cdfa-416a-b4a2-09b24f44dcc5  Kelly reminisced about how much she loved her ...
# e0cab669-993a-41be-978f-97795be07197             He decided to go out for a short walk.
# ad2236b7-de48-45a2-838b-25f166bdee90  He spent every weekend getting better with his...
# 500fe4a4-f7c4-4f46-96ee-e010467b069f                    Tom wanted to go on a fun date.
# 522f2bc3-3bb1-4f68-8e99-5b2abd016854      She paid rent then asked for some of it back.
#
#                                                                               sentence3  \
# storyid
# 8eb647c6-cdfa-416a-b4a2-09b24f44dcc5  Kelly decided that she was going to try to mak...
# e0cab669-993a-41be-978f-97795be07197  It was a very windy day, but he wasn't too con...
# ad2236b7-de48-45a2-838b-25f166bdee90  One day he was offered a TV show about grillin...
# 500fe4a4-f7c4-4f46-96ee-e010467b069f                         Tom suggested ice skating.
# 522f2bc3-3bb1-4f68-8e99-5b2abd016854              She drinks my juice and eats my food.
#
#                                                                               sentence4  \
# storyid
# 8eb647c6-cdfa-416a-b4a2-09b24f44dcc5  Kelly studied the recipe and gathered everythi...
# e0cab669-993a-41be-978f-97795be07197  Suddenly, a strong wind came through and took ...
# ad2236b7-de48-45a2-838b-25f166bdee90              Jimmy accepted the job in an instant.
# 500fe4a4-f7c4-4f46-96ee-e010467b069f    His date was excited and they went ice skating.
# 522f2bc3-3bb1-4f68-8e99-5b2abd016854     She also makes a huge mess and is very sloppy.
#
#                                                                               sentence5
# storyid
# 8eb647c6-cdfa-416a-b4a2-09b24f44dcc5  Kelly successfully made a pizza from her grand...
# e0cab669-993a-41be-978f-97795be07197  His dog leaped and caught it, and he quickly r...
# ad2236b7-de48-45a2-838b-25f166bdee90  He quit his day job and spent all his time gri...
# 500fe4a4-f7c4-4f46-96ee-e010467b069f  Tom and Beth grew closer during their ice skat...
# 522f2bc3-3bb1-4f68-8e99-5b2abd016854                   She got kicked out in two weeks.

# %%
stories.dtypes
# Out:
# storytitle    object
# sentence1     object
# sentence2     object
# sentence3     object
# sentence4     object
# sentence5     object
# dtype: object

# %%
stories.describe()
# Out:
#        storytitle                  sentence1              sentence2  \
# count       88161                      88161                  88161
# unique      60012                      87311                  87358
# top       Fishing  Tom was out with friends.  She was very nervous.
# freq           75                         11                     17
#
#                               sentence3          sentence4  \
# count                             88161              88161
# unique                            87728              87713
# top     She bought all the ingredients.  It was delicious.
# freq                                 10                  9
#
#                     sentence5
# count                   88161
# unique                  87745
# top     She had a great time.
# freq                       12

# %%
stories.duplicated().sum()
# Out:
# 5

# %%
stories[stories.duplicated()]
# Out:
#                                                       storytitle  \
# storyid
# 571977cb-767f-4dc9-8dc5-22270288640b  Arranging the place cards.
# 2355dbcf-eb90-41ab-b29e-8b4664022c37                Bedbug issue
# d5ff8fc6-a63d-4b8d-bf49-20f60856f7c5                   school id
# dc3f3656-9428-462a-b2ad-5a679af84251                    The Baby
# 83b0efb7-e9a0-4838-941f-07ef2ef73997                 Mary's Walk
#
#                                                                             sentence1  \
# storyid
# 571977cb-767f-4dc9-8dc5-22270288640b   Daniel was setting up for Thanksgiving dinner.
# 2355dbcf-eb90-41ab-b29e-8b4664022c37               Seema had welts all over her body.
# d5ff8fc6-a63d-4b8d-bf49-20f60856f7c5  Me and my friends went to the park after class.
# dc3f3656-9428-462a-b2ad-5a679af84251     Amy unexpectedly found out she was pregnant.
# 83b0efb7-e9a0-4838-941f-07ef2ef73997                   Mary decided to go for a walk.
#
#                                                                               sentence2  \
# storyid
# 571977cb-767f-4dc9-8dc5-22270288640b    She needed to arrange place cards for everyone.
# 2355dbcf-eb90-41ab-b29e-8b4664022c37       She visited the dermatologist for a checkup.
# d5ff8fc6-a63d-4b8d-bf49-20f60856f7c5  We decided to go home because it's already get...
# dc3f3656-9428-462a-b2ad-5a679af84251  At first she was not excited and was very nerv...
# 83b0efb7-e9a0-4838-941f-07ef2ef73997               While walking, she tripped and fell.
#
#                                                                               sentence3  \
# storyid
# 571977cb-767f-4dc9-8dc5-22270288640b  At first she put her brother and uncle near ea...
# 2355dbcf-eb90-41ab-b29e-8b4664022c37  The dermatologist said it's bedbug bites and p...
# d5ff8fc6-a63d-4b8d-bf49-20f60856f7c5    When i got home i noticed my school is missing.
# dc3f3656-9428-462a-b2ad-5a679af84251  As time went on, she became very excited to ha...
# 83b0efb7-e9a0-4838-941f-07ef2ef73997                                 She broke her leg.
#
#                                                                               sentence4  \
# storyid
# 571977cb-767f-4dc9-8dc5-22270288640b  Then, her sister warned her that the two had b...
# 2355dbcf-eb90-41ab-b29e-8b4664022c37  She also called the pest control and had sever...
# d5ff8fc6-a63d-4b8d-bf49-20f60856f7c5   I asked my friends if they saw but they did not.
# dc3f3656-9428-462a-b2ad-5a679af84251         She couldn't wait for the baby to be born.
# 83b0efb7-e9a0-4838-941f-07ef2ef73997             A passing driver stopped to help Mary.
#
#                                                                               sentence5
# storyid
# 571977cb-767f-4dc9-8dc5-22270288640b  She managed to change the arrangement right be...
# 2355dbcf-eb90-41ab-b29e-8b4664022c37  Finally, she got rid of the bedbugs and the we...
# d5ff8fc6-a63d-4b8d-bf49-20f60856f7c5    I went back to the park and luckily i found it.
# dc3f3656-9428-462a-b2ad-5a679af84251  When the baby was finally born, she was overjo...
# 83b0efb7-e9a0-4838-941f-07ef2ef73997  The driver took her to the hospital to receive...

# %%
stories17 = pd.read_csv('data/ROCStories_winter2017 - ROCStories_winter2017.csv')
stories17.set_index('storyid', inplace=True)
stories17.head()
# Out:
#                                                    storytitle  \
# storyid
# 8bbe6d11-1e2e-413c-bf81-eaea05f4f1bd   David Drops the Weight
# 0beabab2-fb49-460e-a6e6-f35a202e3348              Frustration
# 87da1a22-df0b-410c-b186-439700b70ba6       Marcus Buys Khakis
# 2d16bcd6-692a-4fc0-8e7c-4a6f81d9efa9       Different Opinions
# c71bb23b-7731-4233-8298-76ba6886cee1  Overcoming shortcomings
#
#                                                                               sentence1  \
# storyid
# 8bbe6d11-1e2e-413c-bf81-eaea05f4f1bd  David noticed he had put on a lot of weight re...
# 0beabab2-fb49-460e-a6e6-f35a202e3348                       Tom had a very short temper.
# 87da1a22-df0b-410c-b186-439700b70ba6  Marcus needed clothing for a business casual e...
# 2d16bcd6-692a-4fc0-8e7c-4a6f81d9efa9  Bobby thought Bill should buy a trailer and ha...
# c71bb23b-7731-4233-8298-76ba6886cee1          John was a pastor with a very bad memory.
#
#                                                                               sentence2  \
# storyid
# 8bbe6d11-1e2e-413c-bf81-eaea05f4f1bd  He examined his habits to try and figure out t...
# 0beabab2-fb49-460e-a6e6-f35a202e3348               One day a guest made him very angry.
# 87da1a22-df0b-410c-b186-439700b70ba6  All of his clothes were either too formal or t...
# 2d16bcd6-692a-4fc0-8e7c-4a6f81d9efa9  Bill thought a truck would be better for what ...
# c71bb23b-7731-4233-8298-76ba6886cee1  He tried to memorize his sermons many days in ...
#
#                                                                               sentence3  \
# storyid
# 8bbe6d11-1e2e-413c-bf81-eaea05f4f1bd  He realized he'd been eating too much fast foo...
# 0beabab2-fb49-460e-a6e6-f35a202e3348        He punched a hole in the wall of his house.
# 87da1a22-df0b-410c-b186-439700b70ba6                He decided to buy a pair of khakis.
# 2d16bcd6-692a-4fc0-8e7c-4a6f81d9efa9  Bobby pointed out two vehicles were much more ...
# c71bb23b-7731-4233-8298-76ba6886cee1  He decided to learn to sing to overcome his ha...
#
#                                                                               sentence4  \
# storyid
# 8bbe6d11-1e2e-413c-bf81-eaea05f4f1bd  He stopped going to burger places and started ...
# 0beabab2-fb49-460e-a6e6-f35a202e3348        Tom's guest became afraid and left quickly.
# 87da1a22-df0b-410c-b186-439700b70ba6              The pair he bought fit him perfectly.
# 2d16bcd6-692a-4fc0-8e7c-4a6f81d9efa9  Bill was set in his ways with conventional thi...
# c71bb23b-7731-4233-8298-76ba6886cee1  He then made all his sermons into music and sa...
#
#                                                                               sentence5
# storyid
# 8bbe6d11-1e2e-413c-bf81-eaea05f4f1bd  After a few weeks, he started to feel much bet...
# 0beabab2-fb49-460e-a6e6-f35a202e3348  Tom sat on his couch filled with regret about ...
# 87da1a22-df0b-410c-b186-439700b70ba6  Marcus was happy to have the right clothes for...
# 2d16bcd6-692a-4fc0-8e7c-4a6f81d9efa9  He ended up buying the truck he wanted despite...
# c71bb23b-7731-4233-8298-76ba6886cee1      His congregation was delighted and so was he.

# %%
stories17.describe()
# Out:
#        storytitle                  sentence1              sentence2  \
# count       52665                      52665                  52665
# unique      37537                      52050                  52198
# top       Fishing  Tom was out with friends.  She was very nervous.
# freq           46                         12                     13
#
#                               sentence3  \
# count                             52665
# unique                            52407
# top     She bought all the ingredients.
# freq                                 11
#
#                                             sentence4              sentence5
# count                                           52665                  52665
# unique                                          52401                  52388
# top     He searched everywhere and could not find it.  She had a great time.
# freq                                                9                     15

# %%
stories17.duplicated().sum()
# Out:
# 1

# %%
stories16 = pd.read_csv('data/ROCStories__spring2016 - ROCStories_spring2016.csv')
stories16.set_index('storyid', inplace=True)
stories16.head()
# Out:
#                                              storytitle  \
# storyid
# 9a51198e-96f1-42c3-b09d-a3e1e067d803     Overweight Kid
# 617e7ada-3878-488d-bd56-40695b91f053  The Bike Accident
# 79b0da1f-e460-4173-ba58-8c9e2553c53a              Beach
# d173b7de-4611-4cdf-934c-912834755e41  The bad customer.
# af0fd5a4-de36-47ba-8aa2-e99d10986d7a      Being Patient
#
#                                                                         sentence1  \
# storyid
# 9a51198e-96f1-42c3-b09d-a3e1e067d803               Dan's parents were overweight.
# 617e7ada-3878-488d-bd56-40695b91f053  Carrie had just learned how to ride a bike.
# 79b0da1f-e460-4173-ba58-8c9e2553c53a      Morgan enjoyed long walks on the beach.
# d173b7de-4611-4cdf-934c-912834755e41                 Jane was working at a diner.
# af0fd5a4-de36-47ba-8aa2-e99d10986d7a             I was talking to my crush today.
#
#                                                                               sentence2  \
# storyid
# 9a51198e-96f1-42c3-b09d-a3e1e067d803                        Dan was overweight as well.
# 617e7ada-3878-488d-bd56-40695b91f053                 She didn't have a bike of her own.
# 79b0da1f-e460-4173-ba58-8c9e2553c53a  She and her boyfriend decided to go for a long...
# d173b7de-4611-4cdf-934c-912834755e41     Suddenly, a customer barged up to the counter.
# af0fd5a4-de36-47ba-8aa2-e99d10986d7a  She continued to complain about guys flirting ...
#
#                                                                               sentence3  \
# storyid
# 9a51198e-96f1-42c3-b09d-a3e1e067d803     The doctors told his parents it was unhealthy.
# 617e7ada-3878-488d-bd56-40695b91f053     Carrie would sneak rides on her sister's bike.
# 79b0da1f-e460-4173-ba58-8c9e2553c53a  After walking for over a mile, something happe...
# d173b7de-4611-4cdf-934c-912834755e41  He began yelling about how long his food was t...
# af0fd5a4-de36-47ba-8aa2-e99d10986d7a  I decided to agree with what she says and list...
#
#                                                                               sentence4  \
# storyid
# 9a51198e-96f1-42c3-b09d-a3e1e067d803  His parents understood and decided to make a c...
# 617e7ada-3878-488d-bd56-40695b91f053  She got nervous on a hill and crashed into a w...
# 79b0da1f-e460-4173-ba58-8c9e2553c53a        Morgan decided to propose to her boyfriend.
# d173b7de-4611-4cdf-934c-912834755e41                     Jane didn't know how to react.
# af0fd5a4-de36-47ba-8aa2-e99d10986d7a           After I got home, I got a text from her.
#
#                                                                               sentence5
# storyid
# 9a51198e-96f1-42c3-b09d-a3e1e067d803             They got themselves and Dan on a diet.
# 617e7ada-3878-488d-bd56-40695b91f053  The bike frame bent and Carrie got a deep gash...
# 79b0da1f-e460-4173-ba58-8c9e2553c53a  Her boyfriend was upset he didn't propose to h...
# d173b7de-4611-4cdf-934c-912834755e41  Luckily, her coworker intervened and calmed th...
# af0fd5a4-de36-47ba-8aa2-e99d10986d7a             She asked if we can hang out tomorrow.

# %%
stories16.duplicated().sum()
# Out:
# 4

# %%
all_stories = pd.concat((stories16, stories17))

# %%
all_stories.describe()
# Out:
#        storytitle                  sentence1              sentence2  \
# count       98161                      98161                  98161
# unique      65735                      97168                  97214
# top       Fishing  Tom was out with friends.  She was very nervous.
# freq           87                         12                     20
#
#                               sentence3          sentence4  \
# count                             98161              98161
# unique                            97659              97619
# top     She bought all the ingredients.  It was delicious.
# freq                                 13                  9
#
#                     sentence5
# count                   98161
# unique                  97647
# top     She had a great time.
# freq                       15

# %%
all_stories.duplicated().sum()
# Out:
# 5

# %%
all_stories.drop_duplicates(inplace=True)

# %%
all_stories.to_csv('data/all_stories.csv')

# %%
len(stories)
# Out:
# 88161

# %%
stories.isin(all_stories).sum()
# Out:
# storytitle    88156
# sentence1     88156
# sentence2     88156
# sentence3     88156
# sentence4     88156
# sentence5     88156
# dtype: int64

# %%
len(all_stories)
# Out:
# 98156

# %% [markdown]
# # Training data

# %% [markdown]
# We will generate negative samples by sampling randomly from the dataset

# %%
train_pos = all_stories.copy()
train_pos.reset_index(drop=True, inplace=True)
train_pos['label'] = 1
train_pos.head()
# Out:
#           storytitle                                    sentence1  \
# 0     Overweight Kid               Dan's parents were overweight.
# 1  The Bike Accident  Carrie had just learned how to ride a bike.
# 2              Beach      Morgan enjoyed long walks on the beach.
# 3  The bad customer.                 Jane was working at a diner.
# 4      Being Patient             I was talking to my crush today.
#
#                                            sentence2  \
# 0                        Dan was overweight as well.
# 1                 She didn't have a bike of her own.
# 2  She and her boyfriend decided to go for a long...
# 3     Suddenly, a customer barged up to the counter.
# 4  She continued to complain about guys flirting ...
#
#                                            sentence3  \
# 0     The doctors told his parents it was unhealthy.
# 1     Carrie would sneak rides on her sister's bike.
# 2  After walking for over a mile, something happe...
# 3  He began yelling about how long his food was t...
# 4  I decided to agree with what she says and list...
#
#                                            sentence4  \
# 0  His parents understood and decided to make a c...
# 1  She got nervous on a hill and crashed into a w...
# 2        Morgan decided to propose to her boyfriend.
# 3                     Jane didn't know how to react.
# 4           After I got home, I got a text from her.
#
#                                            sentence5  label
# 0             They got themselves and Dan on a diet.      1
# 1  The bike frame bent and Carrie got a deep gash...      1
# 2  Her boyfriend was upset he didn't propose to h...      1
# 3  Luckily, her coworker intervened and calmed th...      1
# 4             She asked if we can hang out tomorrow.      1

# %%
train_neg = train_pos.copy()
neg_last_sentence = np.random.choice(neg_samples.sentence5, size=len(neg_samples))
train_neg['sentence5'] = neg_last_sentence
train_neg.label = 0
train_neg.head()
# Out:
#           storytitle                                    sentence1  \
# 0     Overweight Kid               Dan's parents were overweight.
# 1  The Bike Accident  Carrie had just learned how to ride a bike.
# 2              Beach      Morgan enjoyed long walks on the beach.
# 3  The bad customer.                 Jane was working at a diner.
# 4      Being Patient             I was talking to my crush today.
#
#                                            sentence2  \
# 0                        Dan was overweight as well.
# 1                 She didn't have a bike of her own.
# 2  She and her boyfriend decided to go for a long...
# 3     Suddenly, a customer barged up to the counter.
# 4  She continued to complain about guys flirting ...
#
#                                            sentence3  \
# 0     The doctors told his parents it was unhealthy.
# 1     Carrie would sneak rides on her sister's bike.
# 2  After walking for over a mile, something happe...
# 3  He began yelling about how long his food was t...
# 4  I decided to agree with what she says and list...
#
#                                            sentence4  \
# 0  His parents understood and decided to make a c...
# 1  She got nervous on a hill and crashed into a w...
# 2        Morgan decided to propose to her boyfriend.
# 3                     Jane didn't know how to react.
# 4           After I got home, I got a text from her.
#
#                                            sentence5  label
# 0  Kelli realized she washed her face with mouthw...      0
# 1          The stewardess had to help calm him down.      0
# 2  Despite her doubts, however, she was awarded a...      0
# 3                    Courtney was glad to see again.      0
# 4                   The best dancer won the contest.      0

# %%
train = pd.concat((train_pos, train_neg))
train = train.sample(frac=1.)  # Shuffle
train.head()
# Out:
#              storytitle                                          sentence1  \
# 64031  Beggar's Delight  A beggar stood on a street corner and panhandled.
# 26490     Spilled juice        Last night I was drinking some grape juice.
# 30131         Microchip               Kate wanted to develop a micro chip.
# 18009  Cherry lip gloss  Sally's crush Bill commented how good her lip ...
# 39848    The Little Boy                       Annie never knew his father.
#
#                                                sentence2  \
# 64031  When times were slow he would write small stor...
# 26490                                 I had two glasses.
# 30131                Kate drew all the designs on paper.
# 18009  She was holding the tube because she had just ...
# 39848  He lived alone with his mother and worked for ...
#
#                                                sentence3  \
# 64031  A person came by and refused to give the man a...
# 26490  Unfortunately when I was drinking it, I spille...
# 30131  Kate took her idea to a leading computer company.
# 18009            She asked him if he wanted to try some.
# 39848  The man was strict but fair and treated Annie ...
#
#                                                sentence4  \
# 64031  The beggar offered to sell one of his stories ...
# 26490                              It went on the couch.
# 30131           The company loved the micro chip design.
# 18009                                       He said yes.
# 39848  One day, he offered Annie an extra job to make...
#
#                                                sentence5  label
# 64031  However, he feels very happy to be getting in ...      0
# 26490            I immediately had to get stain remover.      1
# 30131  Kate successfully sold her design to the company.      1
# 18009  I'm probably going to have to end up firing th...      0
# 39848     Unfortunately, it was all crushed into pieces.      0

# %%
train.to_csv('data/train.csv', index=False)

# %% [markdown]
# # Val data

# %%
all_val = pd.read_csv('data/cloze_test_val__spring2016 - cloze_test_ALL_val.csv')
# val.set_index('storyid', inplace=True)
all_val.head()
# Out:
#                            InputStoryid  \
# 0  138d5bfb-05cc-41e3-bf2c-fa85ebad14e2
# 1  bff9f820-9605-4875-b9af-fe6f14d04256
# 2  e8f628d5-9f97-40ed-8611-fc0e774673c4
# 3  f5226bfe-9f26-4377-b05f-3d9568dbdec1
# 4  69ac9b05-b956-402f-9fff-1f926ef9176b
#
#                                       InputSentence1  \
# 0              Rick grew up in a troubled household.
# 1  Laverne needs to prepare something for her fri...
# 2  Sarah had been dreaming of visiting Europe for...
# 3  Gina was worried the cookie dough in the tube ...
# 4     It was  my final performance in marching band.
#
#                                       InputSentence2  \
# 0  He never found good support in family, and tur...
# 1           She decides to bake a batch of brownies.
# 2         She had finally saved enough for the trip.
# 3          She was very happy to find she was wrong.
# 4          I was playing the snare drum in the band.
#
#                                       InputSentence3  \
# 0  It wasn't long before Rick got shot in a robbery.
# 1       She chooses a recipe and follows it closely.
# 2  She landed in Spain and traveled east across t...
# 3  The cookies from the tube were as good as from...
# 4                 We played Thriller and Radar Love.
#
#                                       InputSentence4  \
# 0        The incident caused him to turn a new leaf.
# 1  Laverne tests one of the brownies to make sure...
# 2      She didn't like how different everything was.
# 3  Gina intended to only eat 2 cookies and save t...
# 4                      The performance was flawless.
#
#                             RandomFifthSentenceQuiz1  \
# 0                                   He is happy now.
# 1  The brownies are so delicious Laverne eats two...
# 2              Sarah then decided to move to Europe.
# 3  Gina liked the cookies so much she ate them al...
# 4                I was very proud of my performance.
#
#                             RandomFifthSentenceQuiz2  AnswerRightEnding
# 0                                  He joined a gang.                  1
# 1          Laverne doesn't go to her friend's party.                  1
# 2  Sarah decided that she preferred her home over...                  2
# 3          Gina gave the cookies away at her church.                  1
# 4              I was very ashamed of my performance.                  1

# %%
all_val.drop(labels=['InputStoryid'], axis=1, inplace=True)
all_val.columns = ['sentence1', 'sentence2', 'sentence3', 'sentence4', 'random1', 'random2', 'answer']
all_val.head()
# Out:
#                                            sentence1  \
# 0              Rick grew up in a troubled household.
# 1  Laverne needs to prepare something for her fri...
# 2  Sarah had been dreaming of visiting Europe for...
# 3  Gina was worried the cookie dough in the tube ...
# 4     It was  my final performance in marching band.
#
#                                            sentence2  \
# 0  He never found good support in family, and tur...
# 1           She decides to bake a batch of brownies.
# 2         She had finally saved enough for the trip.
# 3          She was very happy to find she was wrong.
# 4          I was playing the snare drum in the band.
#
#                                            sentence3  \
# 0  It wasn't long before Rick got shot in a robbery.
# 1       She chooses a recipe and follows it closely.
# 2  She landed in Spain and traveled east across t...
# 3  The cookies from the tube were as good as from...
# 4                 We played Thriller and Radar Love.
#
#                                            sentence4  \
# 0        The incident caused him to turn a new leaf.
# 1  Laverne tests one of the brownies to make sure...
# 2      She didn't like how different everything was.
# 3  Gina intended to only eat 2 cookies and save t...
# 4                      The performance was flawless.
#
#                                              random1  \
# 0                                   He is happy now.
# 1  The brownies are so delicious Laverne eats two...
# 2              Sarah then decided to move to Europe.
# 3  Gina liked the cookies so much she ate them al...
# 4                I was very proud of my performance.
#
#                                              random2  answer
# 0                                  He joined a gang.       1
# 1          Laverne doesn't go to her friend's party.       1
# 2  Sarah decided that she preferred her home over...       2
# 3          Gina gave the cookies away at her church.       1
# 4              I was very ashamed of my performance.       1

# %%
val_pos = all_val.copy()

# %%
val_pos.lookup(val_pos.index, 'random' + val_pos.answer.astype('str'))
# Out:
# array(['He is happy now.',
#        'The brownies are so delicious Laverne eats two of them.',
#        'Sarah decided that she preferred her home over Europe.', ...,
#        'John was glad he asked her on a date.',
#        'The flute sounded beautiful.',
#        'The ride was very fun for Maggie.'], dtype=object)

# %%
val_pos = all_val.copy()

val_pos_last_sentence = val_pos.lookup(val_pos.index, 'random' + val_pos.answer.astype('str'))
val_pos['sentence5'] = val_pos_last_sentence

val_pos.drop(labels=['random1', 'random2', 'answer'], axis=1, inplace=True)
val_pos['label'] = 1

val_pos.head()
# Out:
#                                            sentence1  \
# 0              Rick grew up in a troubled household.
# 1  Laverne needs to prepare something for her fri...
# 2  Sarah had been dreaming of visiting Europe for...
# 3  Gina was worried the cookie dough in the tube ...
# 4     It was  my final performance in marching band.
#
#                                            sentence2  \
# 0  He never found good support in family, and tur...
# 1           She decides to bake a batch of brownies.
# 2         She had finally saved enough for the trip.
# 3          She was very happy to find she was wrong.
# 4          I was playing the snare drum in the band.
#
#                                            sentence3  \
# 0  It wasn't long before Rick got shot in a robbery.
# 1       She chooses a recipe and follows it closely.
# 2  She landed in Spain and traveled east across t...
# 3  The cookies from the tube were as good as from...
# 4                 We played Thriller and Radar Love.
#
#                                            sentence4  \
# 0        The incident caused him to turn a new leaf.
# 1  Laverne tests one of the brownies to make sure...
# 2      She didn't like how different everything was.
# 3  Gina intended to only eat 2 cookies and save t...
# 4                      The performance was flawless.
#
#                                            sentence5  label
# 0                                   He is happy now.      1
# 1  The brownies are so delicious Laverne eats two...      1
# 2  Sarah decided that she preferred her home over...      1
# 3  Gina liked the cookies so much she ate them al...      1
# 4                I was very proud of my performance.      1

# %%
val_neg = all_val.copy()

# 1 -> 2, 2 -> 1, to get the negative samples
val_neg_last_sentence = val_neg.lookup(val_neg.index, 
                                       'random' + (3 - val_neg.answer).astype('str'))
val_neg['sentence5'] = val_neg_last_sentence

val_neg.drop(labels=['random1', 'random2', 'answer'], axis=1, inplace=True)
val_neg['label'] = 0

val_neg.head()
# Out:
#                                            sentence1  \
# 0              Rick grew up in a troubled household.
# 1  Laverne needs to prepare something for her fri...
# 2  Sarah had been dreaming of visiting Europe for...
# 3  Gina was worried the cookie dough in the tube ...
# 4     It was  my final performance in marching band.
#
#                                            sentence2  \
# 0  He never found good support in family, and tur...
# 1           She decides to bake a batch of brownies.
# 2         She had finally saved enough for the trip.
# 3          She was very happy to find she was wrong.
# 4          I was playing the snare drum in the band.
#
#                                            sentence3  \
# 0  It wasn't long before Rick got shot in a robbery.
# 1       She chooses a recipe and follows it closely.
# 2  She landed in Spain and traveled east across t...
# 3  The cookies from the tube were as good as from...
# 4                 We played Thriller and Radar Love.
#
#                                            sentence4  \
# 0        The incident caused him to turn a new leaf.
# 1  Laverne tests one of the brownies to make sure...
# 2      She didn't like how different everything was.
# 3  Gina intended to only eat 2 cookies and save t...
# 4                      The performance was flawless.
#
#                                    sentence5  label
# 0                          He joined a gang.      0
# 1  Laverne doesn't go to her friend's party.      0
# 2      Sarah then decided to move to Europe.      0
# 3  Gina gave the cookies away at her church.      0
# 4      I was very ashamed of my performance.      0

# %%
val.describe()
# Out:
#        AnswerRightEnding
# count        1871.000000
# mean            1.485836
# std             0.499933
# min             1.000000
# 25%             1.000000
# 50%             1.000000
# 75%             2.000000
# max             2.000000

# %%
val = pd.concat((val_pos, val_neg))
val = val.sample(frac=1.)  # Shuffle
val.head()
# Out:
#                                               sentence1  \
# 1412  Robert's dog passed away last month and he's s...
# 682   My brother kept fighting me for the remote las...
# 654                   Sara works next door to a bakery.
# 516   Ora had been dared not to shower in order to j...
# 1572                        Dorothy's cat was pregnant.
#
#                                               sentence2  \
# 1412  His wife wants to distract Robert with something.
# 682               Finally we decided to divide its use.
# 654         She is on a diet so she can never go there.
# 516   She couldn't imagine going without clean water...
# 1572                   She didn't know how it happened.
#
#                                             sentence3  \
# 1412     She suggests they go shopping for a new dog.
# 682             We would each get to have it one day.
# 654   One day she notices the bakery has closed down.
# 516                   Then she thought of a loophole.
# 1572    She convinced the family to keep the kittens.
#
#                                               sentence4  \
# 1412  Robert tags along and discovers that he loves ...
# 682   My brother then got into a fight who should ha...
# 654   The next week a healthy organic juice shop opens.
# 516          They hadn't said Ora couldn't take a bath!
# 1572                      It wound up having 7 kittens.
#
#                                               sentence5  label
# 1412  Robert starts to feel better after playing wit...      1
# 682           I never watch television with my brother.      0
# 654                The food was too unhealthy for Sara.      0
# 516                                  Ora took a shower.      0
# 1572         Dorothy made sure to buy lots of cat food.      1

# %%
val.to_csv('data/val.csv', index=False)

# %% [markdown]
# # Test data

# %%
all_test = pd.read_csv('data/cloze_test_test__spring2016 - cloze_test_ALL_test.csv')
# val.set_index('storyid', inplace=True)
all_test.head()
# Out:
#                            InputStoryid  \
# 0  b929f263-1dcd-4a0b-b267-5d5ff2fe65bb
# 1  7cbbc0af-bcce-4f56-871d-963f9bb6a99d
# 2  4745d627-be9b-45f2-ad92-99c82cc83f85
# 3  6bc5a855-3a02-454c-8d8b-4428b1864f95
# 4  2f74e81d-957b-4541-9e66-59e5eaa6aef1
#
#                                     InputSentence1  \
# 0  My friends all love to go to the club to dance.
# 1         I tried going to the park the other day.
# 2                 Avery was married with children.
# 3         Josh loved when his mom baked apple pie.
# 4       John was writing lyrics for his new album.
#
#                                       InputSentence2  \
# 0    They think it's a lot of fun and always invite.
# 1         The weather seemed nice enough for a walk.
# 2                  She was tired of her boring life.
# 3  He hated how he always had to wait until after...
# 4            He started experiencing writer's block.
#
#                                       InputSentence3  \
# 0      I finally decided to tag along last Saturday.
# 1  Within minutes of getting there I started snee...
# 2  One day, she decided to meet up with an old bo...
# 3  So he decided this time he would sneak a piece...
# 4  He tried to force himself to write but it woul...
#
#                                       InputSentence4  \
# 0        I danced terribly and broke a friend's toe.
# 1    My eyes were watery and it was hard to breathe.
# 2  She made poor decisions that night and was unf...
# 3   The eggs his mom used must have been bad though.
# 4  He took a walk, hung out with some friends, an...
#
#                             RandomFifthSentenceQuiz1  \
# 0  My friends decided to keep inviting me out as ...
# 1  My allergies were too bad and I had to go back...
# 2  Avery thought her children would be happy with...
# 3           Josh thought that the pie was delicious.
# 4  He felt inspiration and then went back home to...
#
#                             RandomFifthSentenceQuiz2  AnswerRightEnding
# 0  The next weekend, I was asked to please stay h...                  2
# 1  It reminded me of how much I loved spring flow...                  1
# 2         Avery regretted what she did the next day.                  2
# 3                                     Josh got sick.                  2
# 4            John then got an idea for his painting.                  1

# %%
all_test.drop(labels=['InputStoryid'], axis=1, inplace=True)
all_test.columns = ['sentence1', 'sentence2', 'sentence3', 'sentence4', 'random1', 'random2', 'answer']


test_pos = all_test.copy()

test_pos_last_sentence = test_pos.lookup(test_pos.index, 'random' + test_pos.answer.astype('str'))
test_pos['sentence5'] = test_pos_last_sentence

test_pos.drop(labels=['random1', 'random2', 'answer'], axis=1, inplace=True)
test_pos['label'] = 1


test_neg = all_test.copy()

# 1 -> 2, 2 -> 1, to get the negative samples
test_neg_last_sentence = test_neg.lookup(test_neg.index, 
                                       'random' + (3 - test_neg.answer).astype('str'))
test_neg['sentence5'] = test_neg_last_sentence

test_neg.drop(labels=['random1', 'random2', 'answer'], axis=1, inplace=True)
test_neg['label'] = 0


test = pd.concat((test_pos, test_neg))
test = val.sample(frac=1.)  # Shuffle
test.head()
# Out:
#                                               sentence1  \
# 13    Cara went to a food cart in Philadelphia the o...
# 1047                 Last night I marked baked chicken.
# 1439  Meghan was hired as a Scientist II for a company.
# 493   Brianna complained bitterly when her family we...
# 240                  Gina's friend Mary wouldn't share.
#
#                                               sentence2  \
# 13              She stopped by an amazing falafel cart.
# 1047             When I put in the oven, I walked away.
# 1439         She loved her job and was very good at it.
# 493   It would ruin her hair and nails and there was...
# 240   They both needed to use the school library boo...
#
#                                               sentence3  \
# 13                                The food was amazing.
# 1047            To my dismay I smelled something burnt.
# 1439  After a year, Meghan wanted more responsibilit...
# 493   However, she forgot these things when she tast...
# 240        But Mary had beaten Gina and taken them all.
#
#                                               sentence4  \
# 13               Cara couldn't believe how good it was.
# 1047   I looked in the oven and the chicken was ruined.
# 1439      She talked to her boss and had an evaluation.
# 493   Munching her treat, she gazed at the huge, sta...
# 240             And now she refused to share the books.
#
#                                               sentence5  label
# 13         Cara told the owner that the food was awful.      0
# 1047                    I ordered pizza to eat instead.      1
# 1439                    Meghan decided to quit her job.      0
# 493                              Brianna hated s'mores.      0
# 240   Gina's mother had to call Mary's mom to complain.      1

# %%
test.to_csv('data/test.csv', index=False)
